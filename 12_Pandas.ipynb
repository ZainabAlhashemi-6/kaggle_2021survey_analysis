# %% [markdown]
# # Import Data

# %%
import pandas as pd

# %% [markdown]
# # Loading Data

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None,
# ...

# %%
salary_df = pd.read_csv('salary.csv')
salary_df
# Out:
#     salary  gender departm  years   age  publications
# 0    86285       0     bio   26.0  64.0            72
# 1    77125       0     bio   28.0  58.0            43
# 2    71922       0     bio   10.0  38.0            23
# 3    70499       0     bio   16.0  46.0            64
# 4    66624       0     bio   11.0  41.0            23
# ..     ...     ...     ...    ...   ...           ...
# 72   53662       1   neuro    1.0  31.0             3
# 73   57185       1    stat    9.0  39.0             7
# 74   52254       1    stat    2.0  32.0             9
# 75   61885       1    math   23.0  60.0             9
# 76   49542       1    math    3.0  33.0             5
#
# [77 rows x 6 columns]

# %% [markdown]
# # Ways to check dataframe

# %%
salary_df.head()
# Out:
#    salary  gender departm  years   age  publications
# 0   86285       0     bio   26.0  64.0            72
# 1   77125       0     bio   28.0  58.0            43
# 2   71922       0     bio   10.0  38.0            23
# 3   70499       0     bio   16.0  46.0            64
# 4   66624       0     bio   11.0  41.0            23

# %%
salary_df.head(10)
# Out:
#    salary  gender departm  years   age  publications
# 0   86285       0     bio   26.0  64.0            72
# 1   77125       0     bio   28.0  58.0            43
# 2   71922       0     bio   10.0  38.0            23
# 3   70499       0     bio   16.0  46.0            64
# 4   66624       0     bio   11.0  41.0            23
# 5   64451       0     bio   23.0  60.0            44
# 6   64366       0     bio   23.0  53.0            22
# 7   59344       0     bio    5.0  40.0            11
# 8   58560       0     bio    8.0  38.0             8
# 9   58294       0     bio   20.0  50.0            12

# %%
salary_df.tail()
# Out:
#     salary  gender departm  years   age  publications
# 72   53662       1   neuro    1.0  31.0             3
# 73   57185       1    stat    9.0  39.0             7
# 74   52254       1    stat    2.0  32.0             9
# 75   61885       1    math   23.0  60.0             9
# 76   49542       1    math    3.0  33.0             5

# %%
salary_df.sample(10) ## asking python to give us a sample of our dataset, each run it will give you a random sample
# Out:
#     salary  gender departm  years   age  publications
# 48   62557       0    stat   28.0  58.0            14
# 49   61947       0    stat   22.0  58.0            17
# 43   78114       0    stat    8.0  38.0            24
# 17   75382       0    chem   26.0  56.0            39
# 76   49542       1    math    3.0  33.0             5
# 14   97630       0    chem   34.0  64.0            43
# 16   76291       0    chem   29.0  65.0            33
# 22   47021       0    chem    4.0  34.0            12
# 67   53517       2    math    5.0  35.0             5
# 66   53638       0    math    4.0  42.0             8

# %%
salary_df.shape
# Out:
# (77, 6)

# %%
salary_df.size ## gives you number of cells
# Out:
# 462

# %%
salary_df.dtypes ## to find the type of each column
# Out:
# salary            int64
# gender            int64
# departm          object
# years           float64
# age             float64
# publications      int64
# dtype: object

# %%
salary_df.info() ## object is refferring to string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   salary        77 non-null     int64
#  1   gender        77 non-null     int64
#  2   departm       77 non-null     object
#  3   years         76 non-null     float64
#  4   age           76 non-null     float64
#  5   publications  77 non-null     int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 3.7+ KB

# %%
## how to get how many nulls are in the dataset

salary_df.describe()  ## this method only works with nummerical columns
# Out:
#               salary     gender      years        age  publications
# count      77.000000  77.000000  76.000000  76.000000     77.000000
# mean    67748.519481   0.142857  14.973684  45.486842     21.831169
# std     15100.581435   0.387783   8.617770   9.005914     15.240530
# min     44687.000000   0.000000   1.000000  31.000000      3.000000
# 25%     57185.000000   0.000000   8.000000  38.000000      9.000000
# 50%     62607.000000   0.000000  14.000000  44.000000     19.000000
# 75%     75382.000000   0.000000  23.000000  53.000000     33.000000
# max    112800.000000   2.000000  34.000000  65.000000     72.000000

# %% [markdown]
# ## Category in Pandas

# %% [markdown]
# # Selecting a Column
#
# 1- using []
#
# 2- .coulumn name

# %%
salary_df['salary']
# Out:
# 0     86285
# 1     77125
# 2     71922
# 3     70499
# 4     66624
#       ...
# 72    53662
# 73    57185
# 74    52254
# 75    61885
# 76    49542
# Name: salary, Length: 77, dtype: int64

# %%
salary_df.salary
# Out:
# 0     86285
# 1     77125
# 2     71922
# 3     70499
# 4     66624
#       ...
# 72    53662
# 73    57185
# 74    52254
# 75    61885
# 76    49542
# Name: salary, Length: 77, dtype: int64

# %%
pd.set_option('display.max_rows', 50)

# %%
cols = ['salary','age']
salary_df[cols]
# Out:
#     salary   age
# 0    86285  64.0
# 1    77125  58.0
# 2    71922  38.0
# 3    70499  46.0
# 4    66624  41.0
# ..     ...   ...
# 72   53662  31.0
# 73   57185  39.0
# 74   52254  32.0
# 75   61885  60.0
# 76   49542  33.0
#
# [77 rows x 2 columns]

# %%
salary_df[['salary','age']]
# Out:
#     salary   age
# 0    86285  64.0
# 1    77125  58.0
# 2    71922  38.0
# 3    70499  46.0
# 4    66624  41.0
# ..     ...   ...
# 72   53662  31.0
# 73   57185  39.0
# 74   52254  32.0
# 75   61885  60.0
# 76   49542  33.0
#
# [77 rows x 2 columns]

# %% [markdown]
# # Three Types
#
# - DataFrame
# - Series
# - For both you have index

# %%
type(salary_df) ## giving me the type of dataset
# Out:
# pandas.core.frame.DataFrame

# %%
type(salary_df['salary']) ## giving me the type of the 'salary' column
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Create a new column

# %%
salary_df['dubai'] = 'UAE'
salary_df
# Out:
#     salary  gender departm  years   age  publications dubai
# 0    86285       0     bio   26.0  64.0            72   UAE
# 1    77125       0     bio   28.0  58.0            43   UAE
# 2    71922       0     bio   10.0  38.0            23   UAE
# 3    70499       0     bio   16.0  46.0            64   UAE
# 4    66624       0     bio   11.0  41.0            23   UAE
# ..     ...     ...     ...    ...   ...           ...   ...
# 72   53662       1   neuro    1.0  31.0             3   UAE
# 73   57185       1    stat    9.0  39.0             7   UAE
# 74   52254       1    stat    2.0  32.0             9   UAE
# 75   61885       1    math   23.0  60.0             9   UAE
# 76   49542       1    math    3.0  33.0             5   UAE
#
# [77 rows x 7 columns]

# %%
salary_df['monthly salary'] = salary_df['salary']/12
salary_df
# Out:
#     salary  gender departm  years   age  publications dubai  monthly salary
# 0    86285       0     bio   26.0  64.0            72   UAE     7190.416667
# 1    77125       0     bio   28.0  58.0            43   UAE     6427.083333
# 2    71922       0     bio   10.0  38.0            23   UAE     5993.500000
# 3    70499       0     bio   16.0  46.0            64   UAE     5874.916667
# 4    66624       0     bio   11.0  41.0            23   UAE     5552.000000
# ..     ...     ...     ...    ...   ...           ...   ...             ...
# 72   53662       1   neuro    1.0  31.0             3   UAE     4471.833333
# 73   57185       1    stat    9.0  39.0             7   UAE     4765.416667
# 74   52254       1    stat    2.0  32.0             9   UAE     4354.500000
# 75   61885       1    math   23.0  60.0             9   UAE     5157.083333
# 76   49542       1    math    3.0  33.0             5   UAE     4128.500000
#
# [77 rows x 8 columns]

# %%
salary_df['pop'] = salary_df['publications']/salary_df['years']
salary_df
# Out:
#     salary  gender departm  years   age  publications dubai       pop
# 0    86285       0     bio   26.0  64.0            72   UAE  2.769231
# 1    77125       0     bio   28.0  58.0            43   UAE  1.535714
# 2    71922       0     bio   10.0  38.0            23   UAE  2.300000
# 3    70499       0     bio   16.0  46.0            64   UAE  4.000000
# 4    66624       0     bio   11.0  41.0            23   UAE  2.090909
# ..     ...     ...     ...    ...   ...           ...   ...       ...
# 72   53662       1   neuro    1.0  31.0             3   UAE  3.000000
# 73   57185       1    stat    9.0  39.0             7   UAE  0.777778
# 74   52254       1    stat    2.0  32.0             9   UAE  4.500000
# 75   61885       1    math   23.0  60.0             9   UAE  0.391304
# 76   49542       1    math    3.0  33.0             5   UAE  1.666667
#
# [77 rows x 8 columns]

# %%
salary_df.departm.unique() # counting how many departments we have
# Out:
# array(['bio', 'chem', 'geol', 'neuro', 'stat', 'physics', 'math'],
#       dtype=object)

# %%
salary_df.departm.nunique() ## number of unique departments
# Out:
# 7

# %%
salary_df.departm.describe()
# Out:
# count      77
# unique      7
# top       bio
# freq       16
# Name: departm, dtype: object

# %% [markdown]
# # Dropping / Removing columns

# %%
salary_df['monthly salary'] = salary_df['salary']/12
salary_df
# Out:
#     salary  gender departm  years   age  publications dubai       pop  \
# 0    86285       0     bio   26.0  64.0            72   UAE  2.769231
# 1    77125       0     bio   28.0  58.0            43   UAE  1.535714
# 2    71922       0     bio   10.0  38.0            23   UAE  2.300000
# 3    70499       0     bio   16.0  46.0            64   UAE  4.000000
# 4    66624       0     bio   11.0  41.0            23   UAE  2.090909
# ..     ...     ...     ...    ...   ...           ...   ...       ...
# 72   53662       1   neuro    1.0  31.0             3   UAE  3.000000
# 73   57185       1    stat    9.0  39.0             7   UAE  0.777778
# 74   52254       1    stat    2.0  32.0             9   UAE  4.500000
# 75   61885       1    math   23.0  60.0             9   UAE  0.391304
# 76   49542       1    math    3.0  33.0             5   UAE  1.666667
#
#     monthly salary
# 0      7190.416667
# 1      6427.083333
# 2      5993.500000
# 3      5874.916667
# 4      5552.000000
# ...

# %%
salary_df.drop(columns = ['monthly salary'])
# Out:
#     salary  gender departm  years   age  publications dubai       pop
# 0    86285       0     bio   26.0  64.0            72   UAE  2.769231
# 1    77125       0     bio   28.0  58.0            43   UAE  1.535714
# 2    71922       0     bio   10.0  38.0            23   UAE  2.300000
# 3    70499       0     bio   16.0  46.0            64   UAE  4.000000
# 4    66624       0     bio   11.0  41.0            23   UAE  2.090909
# ..     ...     ...     ...    ...   ...           ...   ...       ...
# 72   53662       1   neuro    1.0  31.0             3   UAE  3.000000
# 73   57185       1    stat    9.0  39.0             7   UAE  0.777778
# 74   52254       1    stat    2.0  32.0             9   UAE  4.500000
# 75   61885       1    math   23.0  60.0             9   UAE  0.391304
# 76   49542       1    math    3.0  33.0             5   UAE  1.666667
#
# [77 rows x 8 columns]

# %%
salary_df.drop(columns = ['monthly salary'], inplace = True)

# %% [markdown]
# # Renaming

# %%
salary_df.columns
# Out:
# Index(['salary', 'gender', 'departm', 'years', 'age', 'publications', 'dubai',
#        'pop'],
#       dtype='object')

# %%
columns_dictionary = {"Dubai":"UAE",
                      "pop":"publication per year",
                      "monthly salary":"monthly_salary",
                      "years":"years_of_exp"}

salary_df.rename(columns=columns_dictionary, inplace = True)

# %% [markdown]
# # Mapping Values

# %%
salary_df
# Out:
#     salary  gender departm  years_of_exp   age  publications dubai  \
# 0    86285       0     bio          26.0  64.0            72   UAE
# 1    77125       0     bio          28.0  58.0            43   UAE
# 2    71922       0     bio          10.0  38.0            23   UAE
# 3    70499       0     bio          16.0  46.0            64   UAE
# 4    66624       0     bio          11.0  41.0            23   UAE
# ..     ...     ...     ...           ...   ...           ...   ...
# 72   53662       1   neuro           1.0  31.0             3   UAE
# 73   57185       1    stat           9.0  39.0             7   UAE
# 74   52254       1    stat           2.0  32.0             9   UAE
# 75   61885       1    math          23.0  60.0             9   UAE
# 76   49542       1    math           3.0  33.0             5   UAE
#
#     publication per year
# 0               2.769231
# 1               1.535714
# 2               2.300000
# 3               4.000000
# 4               2.090909
# ...

# %%
gender_dic = {0:"Male",
              1:"female"}
gender_dic
# Out:
# {0: 'Male', 1: 'female'}

# %%
salary_df['gender'].map(gender_dic)
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#        ...
# 72    female
# 73    female
# 74    female
# 75    female
# 76    female
# Name: gender, Length: 77, dtype: object

# %%
salary_df.gender.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   salary                77 non-null     int64
#  1   gender                77 non-null     int64
#  2   departm               77 non-null     object
#  3   years_of_exp          76 non-null     float64
#  4   age                   76 non-null     float64
#  5   publications          77 non-null     int64
#  6   dubai                 77 non-null     object
#  7   publication per year  76 non-null     float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 4.9+ KB

# %%
salary_df.isnull()
# Out:
#     salary  gender  departm  years_of_exp    age  publications  dubai  \
# 0    False   False    False         False  False         False  False
# 1    False   False    False         False  False         False  False
# 2    False   False    False         False  False         False  False
# 3    False   False    False         False  False         False  False
# 4    False   False    False         False  False         False  False
# ..     ...     ...      ...           ...    ...           ...    ...
# 72   False   False    False         False  False         False  False
# 73   False   False    False         False  False         False  False
# 74   False   False    False         False  False         False  False
# 75   False   False    False         False  False         False  False
# 76   False   False    False         False  False         False  False
#
#     publication per year
# 0                  False
# 1                  False
# 2                  False
# ...

# %%
salary_df.isnull().sum()
# Out:
# salary                  0
# gender                  0
# departm                 0
# years_of_exp            1
# age                     1
# publications            0
# dubai                   0
# publication per year    1
# dtype: int64

# %% [markdown]
# # Duplicates

# %%
salary_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# Length: 77, dtype: bool

# %%
salary_df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 salary_df.duplicated().sum()
#
# NameError: name 'salary_df' is not defined

# %% [markdown]
# ### Using Mean,Median, & Mode to fill in gaps

# %%
import pandas as pd

# %%
salary_df = pd.read_csv('salary.csv')
salary_df
# Out:
#     salary  gender departm  years   age  publications
# 0    86285       0     bio   26.0  64.0            72
# 1    77125       0     bio   28.0  58.0            43
# 2    71922       0     bio   10.0  38.0            23
# 3    70499       0     bio   16.0  46.0            64
# 4    66624       0     bio   11.0  41.0            23
# ..     ...     ...     ...    ...   ...           ...
# 72   53662       1   neuro    1.0  31.0             3
# 73   57185       1    stat    9.0  39.0             7
# 74   52254       1    stat    2.0  32.0             9
# 75   61885       1    math   23.0  60.0             9
# 76   49542       1    math    3.0  33.0             5
#
# [77 rows x 6 columns]

# %%
salary_df['age'].mean()
# Out:
# np.float64(45.48684210526316)

# %%
salary_df['age'].median()
# Out:
# np.float64(44.0)

# %%
salary_df['age'].fillna(44)
# Out:
# 0     64.0
# 1     58.0
# 2     38.0
# 3     46.0
# 4     41.0
#       ...
# 72    31.0
# 73    39.0
# 74    32.0
# 75    60.0
# 76    33.0
# Name: age, Length: 77, dtype: float64

# %%
salary_df['age'].fillna(salary_df['age'].median())
# Out:
# 0     64.0
# 1     58.0
# 2     38.0
# 3     46.0
# 4     41.0
#       ...
# 72    31.0
# 73    39.0
# 74    32.0
# 75    60.0
# 76    33.0
# Name: age, Length: 77, dtype: float64

# %%
the_filter = salary_df['age'].isnull()
the_filter
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# Name: age, Length: 77, dtype: bool

# %%
salary_df[the_filter]
# Out:
#     salary  gender departm  years  age  publications
# 18   64762       0    chem   25.0  NaN            29

# %% [markdown]
# - drop nulls
# - fill it only when it exists in real life but not recorded in your data
# -

# %% [markdown]
# ## indexing and selection

# %% [markdown]
# ## series as list

# %%
lst =[1,2,3,4]
lst
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ## series as Dictionary

# %%
import pandas as pd

ser = pd.Series([1,2,3,4])
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
# slicing by implicit index
ser[1:4]
# Out:
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
# slicing by explicit index
ser['B':'D']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # slicing by explicit index
# ----> 2 ser['B':'D']
#
# File ~\miniconda3\Lib\site-packages\pandas\core\series.py:1155, in Series.__getitem__(self, key)
#    1151             return self._get_values_tuple(key)
#    1153 if isinstance(key, slice):
#    1154     # Do slice check before somewhat-costly is_bool_indexer
# -> 1155     return self._getitem_slice(key)
#    1157 if com.is_bool_indexer(key):
#    1158     key = check_bool_indexer(self.index, key)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\generic.py:4368, in NDFrame._getitem_slice(self, key)
#    4363 """
#    4364 __getitem__ for the case where the key is a slice object.
#    4365 """
#    4366 # _convert_slice_indexer to determine if this slice is positional
#    4367 #  or label based, and if the latter, convert to positional
# ...

# %%
# masking
ser[ser > 2]
# Out:
# 2    3
# 3    4
# dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({'name': ['Abdullah', 'Youssef', 'Kawthar', 'Ahmed', 'Russel'],
                   'age': [28, 35, 42, 29, pd.NA],
                    'salary':[10000, 25000, 50000, 19000, 55000],
                    'department':['Software', 'HR', 'Finance', 'ML', 'Data Engineering']})
df
# Out:
#        name   age  salary        department
# 0  Abdullah    28   10000          Software
# 1   Youssef    35   25000                HR
# 2   Kawthar    42   50000           Finance
# 3     Ahmed    29   19000                ML
# 4    Russel  <NA>   55000  Data Engineering

# %%
df[(df['age']>30) & (df['salary'] > 30000)]
# Out:
#       name age  salary department
# 2  Kawthar  42   50000    Finance

# %%
the_filter = {df['department'] == '
